# %% [markdown]
# # YOLOv8 Bone Fracture Detection - Model Training
#
# This notebook trains a YOLOv8 model on the cleaned bone fracture detection dataset.

# %%
# Install ultralytics (YOLOv8)
# %pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.14-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (2.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (1.15.3)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.10.0-2-cp313-none-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.25.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (5.4 kB)
# Requirement already satisfied: psutil>=5.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (5.9.0)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.38.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.38.1 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.38.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.4.14-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading polars-1.38.1-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.4/810.4 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading polars_runtime_32-1.38.1-cp310-abi3-macosx_11_0_arm64.whl (40.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 MB 8.7 MB/s eta 0:00:0000:0100:01
# Downloading torch-2.10.0-2-cp313-none-macosx_11_0_arm64.whl (79.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 14.1 MB/s eta 0:00:00a 0:00:01
# Downloading torchvision-0.25.0-cp313-cp313-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: polars-runtime-32, torch, polars, ultralytics-thop, torchvision, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [ultralytics] [ultralytics]
# Successfully installed polars-1.38.1 polars-runtime-32-1.38.1 torch-2.10.0 torchvision-0.25.0 ultralytics-8.4.14 ultralytics-thop-2.0.18
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from ultralytics import YOLO
import matplotlib.pyplot as plt
import yaml
import torch

# Check what devices are available
print("Device Check:")
print(f"  CUDA available: {torch.cuda.is_available()}")
print(f"  MPS (Apple GPU) available: {torch.backends.mps.is_available() if hasattr(torch.backends, 'mps') else False}")
print(f"  CPU: Always available")

# Determine best device
if torch.cuda.is_available():
    device = 0
    device_name = "CUDA GPU"
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = 'mps'  # Apple Silicon GPU
    device_name = "Apple MPS (GPU)"
else:
    device = 'cpu'
    device_name = "CPU"

print(f"\nUsing device: {device_name} ({device})")
# Out:
# Device Check:
#   CUDA available: False
#   MPS (Apple GPU) available: True
#   CPU: Always available
#
# Using device: Apple MPS (GPU) (mps)

# %%
# Set up paths
# Update this path to point to your cleaned dataset
data_yaml_path = "BoneFractureYolo8/data.yaml"

# Verify the data.yaml file exists and is correct
with open(data_yaml_path, 'r') as f:
    data_config = yaml.safe_load(f)
    print("Dataset Configuration:")
    print(f"  Number of classes: {data_config['nc']}")
    print(f"  Class names: {data_config['names']}")
    print(f"  Train path: {data_config['train']}")
    print(f"  Val path: {data_config['val']}")
    print(f"  Test path: {data_config['test']}")
# Out:
# Dataset Configuration:
#   Number of classes: 6
#   Class names: ['elbow positive', 'fingers positive', 'forearm fracture', 'humerus fracture', 'shoulder fracture', 'wrist positive']
#   Train path: ../train/images
#   Val path: ../valid/images
#   Test path: ../test/images

# %%
# Initialize YOLOv8 model
# Options: 'yolov8n.pt' (nano), 'yolov8s.pt' (small), 'yolov8m.pt' (medium), 
#          'yolov8l.pt' (large), 'yolov8x.pt' (xlarge)
# Start with 'yolov8n.pt' for faster training, or 'yolov8s.pt' for better accuracy
model = YOLO('yolov8n.pt')  # Change to yolov8s.pt, yolov8m.pt, etc. for better accuracy
print(f"Model initialized: {model.model_name}")
# Out:
# Model initialized: yolov8n.pt

# %%
# Train the model
# Device is automatically detected from Cell 2 (will use MPS/GPU if available, otherwise CPU)
results = model.train(
    data=data_yaml_path,
    epochs=100,              # Number of training epochs
    imgsz=640,              # Image size
    batch=16 if device != 'cpu' else 8,  # Larger batch for GPU, smaller for CPU
    name='bone_fracture_yolov8',  # Project name
    project='runs/detect',  # Project directory
    patience=20,            # Early stopping patience
    save=True,              # Save checkpoints
    plots=True,             # Generate training plots
    val=True,               # Validate during training
    device=device,          # Uses device detected in Cell 2 (MPS/GPU/CPU)
    workers=8 if device != 'cpu' else 4,  # More workers for GPU
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.13.5 torch-2.10.0 MPS (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data
0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.23G      1.338      1.023      1.304          8        640: 100% ━━━━━━━━━━━━ 217/217 1.9it/s 1:55<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.9it/s 3.8s0.3s
#                    all        331        176      0.362      0.323      0.299       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      4.23G      1.323      1.018       1.29          8        640: 100% ━━━━━━━━━━━━ 217/217 1.9it/s 1:56<0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.1it/s 3.6s0.3s
#                    all        331        176      0.379       0.29      0.287      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.23G      1.296     0.9934      1.272          5        640: 100% ━━━━━━━━━━━━ 217/217 1.8it/s 2:00<0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.1it/s 3.5s0.3s
#                    all        331        176      0.367      0.292       0.26     0.0954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.23G      1.271      0.981      1.266          9        640: 100% ━━━━━━━━━━━━ 217/217 2.0it/s 1:49<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.7it/s 4.1s0.3s
#                    all        331        176      0.358      0.244       0.26     0.0961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.23G       1.28     0.9979      1.271          3        640: 100% ━━━━━━━━━━━━ 217/217 2.0it/s 1:46<0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.1it/s 3.6s0.3s
#                    all        331        176      0.351      0.271      0.271     0.0961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.23G      1.266     0.9772      1.256         13        640: 100% ━━━━━━━━━━━━ 217/217 1.9it/s 1:56<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.2it/s 3.5s0.3s
#                    all        331        176      0.385      0.243      0.254     0.0979
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.24G      1.253     0.9662      1.246          7        640: 100% ━━━━━━━━━━━━ 217/217 2.0it/s 1:48<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.0it/s 3.6s0.3s
#                    all        331        176      0.507      0.268      0.301      0.112
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.33G      1.222     0.9292      1.222          7        640: 100% ━━━━━━━━━━━━ 217/217 1.8it/s 2:01<0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.0it/s 3.6s0.3s
#                    all        331        176       0.37       0.32      0.293      0.114
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 51, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 71 epochs completed in 2.552 hours.
# Optimizer stripped from /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/runs/detect/bone_fracture_yolov8/weights/last.pt, 6.2MB
# Optimizer stripped from /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/runs/detect/bone_fracture_yolov8/weights/best.pt, 6.2MB
#
# Validating /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/runs/detect/bone_fracture_yolov8/weights/best.pt...
# Ultralytics 8.4.14 🚀 Python-3.13.5 torch-2.10.0 MPS (Apple M4 Pro)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.1s/it 22.9s1.4s
#                    all        331        176      0.412      0.341      0.317      0.118
#         elbow positive         28         29      0.146      0.103     0.0341     0.0129
#       fingers positive         41         48      0.313      0.271      0.224     0.0671
#       forearm fracture         37         43      0.687      0.512      0.547      0.207
#      shoulder fracture         31         36       0.64      0.556      0.552      0.217
#         wrist positive         19         20      0.273      0.264      0.229      0.088
# Speed: 0.2ms preprocess, 41.2ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/runs/detect/bone_fracture_yolov8

# %% [markdown]
# ## Training Results
#
# After training, the model will be saved in `runs/detect/bone_fracture_yolov8/weights/best.pt`

# %%
# Load the best model from training
best_model_path = 'runs/detect/bone_fracture_yolov8/weights/best.pt'
if os.path.exists(best_model_path):
    model = YOLO(best_model_path)
    print(f"Loaded best model from: {best_model_path}")
else:
    print(f"Model not found at {best_model_path}. Training may still be in progress.")
# Out:
# Model not found at runs/detect/bone_fracture_yolov8/weights/best.pt. Training may still be in progress.

# %%
# Validate the model on validation set
metrics = model.val(data=data_yaml_path)
print("\nValidation Metrics:")
print(f"  mAP50: {metrics.box.map50:.4f}")
print(f"  mAP50-95: {metrics.box.map:.4f}")
print(f"  Precision: {metrics.box.mp:.4f}")
print(f"  Recall: {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.14 🚀 Python-3.13.5 torch-2.10.0 CPU (Apple M4 Pro)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 94.0±13.2 MB/s, size: 11.6 KB)
# val: Scanning /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/labels.cache... 348 images, 175 backgrounds, 17 corrupt: 100% ━━━━━━━━━━━━ 348/348 26.5Mit/s 0.0s
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_1090_png.rf.de645f822a5e36175c5e988223f4eeb0.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_111_png.rf.3893d8f7588cea4d796d26119e52637f.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_119_png.rf.77de12cb566fc295603927e2a5b2748a.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_1310_png.rf.daf759fe071a5733142e9847fb388e75.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_1802_png.rf.ada9b0ad89e89af07a36ed5590773b7e.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_1900_png.rf.b5bcead0522f3d8b2bee79cc15a5477f.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_1992_png.rf.379b87658e6c985d51218b5383d5450b.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2027_png.rf.d64c9d07c29a2c6b7b76b6df9f8933e5.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2062_png.rf.96caca3e4789f028ac1329ea33773425.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2128_png.rf.f8b6cd5da365cf54ad4c51ff43bcb9bf.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_213_png.rf.85241ed9c6ce96f4a18e85ec6482b246.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2145_png.rf.a47b00248c5acbae164fa4f06f39861b.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2193_png.rf.9f98385cf14495eb548024eeca646222.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2291_png.rf.62cfeef40c65e7f1fe873335c535e13d.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2487_png.rf.d44e02e62692a0c9e37bdcfc4ef78003.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2552_png.rf.7a87da3fa8c3d03f97c51bcec0ead7e7.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/valid/images/image1_2648_png.rf.c61d3b5957667c312078bb290f1fcc9e.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.4s/it 28.6s1.1ss
#                    all        331        176       0.41      0.348      0.318      0.119
#         elbow positive         28         29      0.127      0.103     0.0335     0.0123
#       fingers positive         41         48      0.314      0.271      0.221     0.0655
#       forearm fracture         37         43      0.687      0.535      0.558      0.214
#      shoulder fracture         31         36      0.669      0.583      0.557      0.219
#         wrist positive         19         20      0.254       0.25       0.22      0.084
# Speed: 0.4ms preprocess, 83.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/val
#
# Validation Metrics:
#   mAP50: 0.3178
#   mAP50-95: 0.1190
#   Precision: 0.4101
#   Recall: 0.3485

# %%
# Run inference on a few test images to visualize predictions
import glob
import cv2

# Get a few test images
test_images_dir = "BoneFractureYolo8/test/images"
test_images = glob.glob(os.path.join(test_images_dir, "*.jpg"))[:5]  # Get first 5 images

# Run predictions
for img_path in test_images:
    results = model.predict(img_path, save=True, conf=0.25)
    print(f"Processed: {img_path}")
# Out:
# image 1/1 /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/test/images/image1_704_png.rf.e3668d404753b933e1fd9500e697ca8c.jpg: 512x640 (no detections), 56.9ms
# Speed: 5.4ms preprocess, 56.9ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/predict
# Processed: BoneFractureYolo8/test/images/image1_704_png.rf.e3668d404753b933e1fd9500e697ca8c.jpg
#
# image 1/1 /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/test/images/image1_1326_png.rf.6019c7e15df84d9d6286932d03e687b6.jpg: 320x640 (no detections), 28.7ms
# Speed: 0.6ms preprocess, 28.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/predict
# Processed: BoneFractureYolo8/test/images/image1_1326_png.rf.6019c7e15df84d9d6286932d03e687b6.jpg
#
# image 1/1 /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/test/images/image2_1718_png.rf.3320525501293fd17921dbca2ec70ebf.jpg: 544x640 1 forearm fracture, 34.6ms
# Speed: 0.9ms preprocess, 34.6ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/predict
# Processed: BoneFractureYolo8/test/images/image2_1718_png.rf.3320525501293fd17921dbca2ec70ebf.jpg
#
# image 1/1 /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/test/images/image2_812_png.rf.cfcd3189eb853066fc4819ad746775a6.jpg: 288x640 (no detections), 27.7ms
# Speed: 0.5ms preprocess, 27.7ms inference, 0.1ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/predict
# Processed: BoneFractureYolo8/test/images/image2_812_png.rf.cfcd3189eb853066fc4819ad746775a6.jpg
#
# image 1/1 /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/BoneFractureYolo8/test/images/image1_6478_png.rf.eee144dfa7e8712592f7d8b10523e2fa.jpg: 640x512 (no detections), 31.3ms
# Speed: 0.8ms preprocess, 31.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /Users/matthewgerges/Documents/Waterloo/4A/MSE446/Term Project/boneFracture/runs/detect/predict
# Processed: BoneFractureYolo8/test/images/image1_6478_png.rf.eee144dfa7e8712592f7d8b10523e2fa.jpg
